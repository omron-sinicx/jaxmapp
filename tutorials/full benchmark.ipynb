# %%
from jaxmapp.utils import viz 
from importlib import reload
reload(viz)

dirname = "../data/eval_data/more_agents"
# dirname = "../data_example/eval_data/example"

viz.visualize_evaluation_results(dirname);
